# %% [markdown]
# ## Data Science Tools and EcoSystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are, in no particular order:
# 1. R
# 2. Python
# 3. Java
# 4. C++
# 5. Ruby
# 6. SQL
# 7. Julia
# 8. Scala

# %% [markdown]
# ### Some of the commonly used Python libraries used by Data Scientists include:
#
# Library Name, Purpose and Use Case
# 1. Pandas, Data Manipulation, Data Preprocessing
# 2. Num Py, Numerical Computing, Array Based Calculations
# 3. Matplotlib, Data Visualization, Visualizing Data Trends
# 4. Seaborn, Statistical Data Visualization, EDA, Statistical Visualizations
# 5. Ploty, Interactive Data Visualization, Presentations
# 6. Scikit-learn, Machine Learning, Predictive Modeling, clustering.
# 7. TensorFlow, Deep Learning and Machine Learning, Deep Learning Models

# %% [markdown]
# ### Data Science Tools Include, and most certainly are not limited too:
#
# | Name of Tool | Purpose | Use Case |
# |------------ | --------- | --------- |
# | Jupyter Lab | Interactive Notebook Environment | Creating Shareable notebooks for Data Analysis |
# | Visual Studio Code | Versatile IDE for Python, R, C++ and more. |
# | R Studio | IDE for R Programming | Statistical Analysis, Visualization and Report Generation |
# | Anaconda Navigator | GUI for managing Python or R Environments | Simplifying environment setup for data analysis |
# | MySQL | Database Querying | Querying large datasets in relational databases |

# %% [markdown]
# ### Below are some elementary examples of arithmetic expressions in Python:

# %%
print(5 + 3) #addition
print(17 - 9) #Subtraction
print(11 / 3) #division
print(6 * 7) #multiplication
print(2 ** 3) #exponentiation
print(17 % 5) #modulo
print(17 // 5) #floor_divion
# Out:
# 8
# 8
# 3.6666666666666665
# 42
# 8
# 2
# 3

# %% [markdown]
# ### Here is a simple arithmetic expression to multiply then add integers.

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ### Converting minutes into hours...

# %% [markdown]
# #### This will simply convert 200 minutes into hours.

# %%
print(200 / 60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ### The objective of this simple notebook is to:

# %% [markdown]
# - Show some popular languages for data science.
# - Show some popular libraries used in data science.
# - Show additional tools used in Data Science.
# - Demonstrate basic Arithmetic in Python

# %% [markdown]
# ### Author: Blake Bannon
